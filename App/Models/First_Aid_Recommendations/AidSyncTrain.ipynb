# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import spacy
import nltk
import datetime
import fasttext
import gensim.downloader as api

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
import json

# %%
with open('D:\\HWAN\\Data\\First_Aid_recommendation.json','r') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data['intents'])

# %%
df
# Out:
#                           tag  \
# 0                        Cuts
# 1                   Abrasions
# 2                      stings
# 3                    Splinter
# 4                     Sprains
# 5                     Strains
# 6                       Fever
# 7            Nasal Congestion
# 8                       Cough
# 9                 Sore Throat
# 10  Gastrointestinal problems
# 11              Skin problems
# 12           Abdonominal Pain
# 13                    Bruises
# 14                 Broken Toe
# 15                    Choking
# 16                      Wound
# 17                   Diarrhea
# 18                 Frost bite
# 19            Heat Exhaustion
# 20                Heat Stroke
# 21               Insect Bites
# 22                 nose bleed
# 23              Pulled Muscle
# 24            Rectal bleeding
# 25                   Sun Burn
# 26              Testicle Pain
# 27                    Vertigo
# 28            Normal Bleeding
# 29                 Eye Injury
# 30              Chemical Burn
# 31                     Poison
# 32                      Teeth
# 33                    seizure
# 34                Head Injury
# 35                   Fainting
# 36                   Headache
# 37                       Cold
# 38                       Rash
# 39                 snake bite
# 40                animal bite
# 41                   Drowning
# 42                        CPR
# 43                   Fracture
#
#                                              patterns  \
# 0   [What to do if Cuts?, How to cure Cuts?, Which...
# 1   [how do you treat abrasions?, Do Abrasions cau...
# 2   [How do you treat Sting?, Stings, What to do i...
# 3   [How to remove Splinters, How to cure Splinter...
# 4   [How do you treat a sprain?, what to do if i g...
# 5   [How do you treat a strain?, what to do if i g...
# 6   [How do you treat a mild Fever?, what to do if...
# 7   [How do you treat nasal Congestion?, what to d...
# 8   [How to cure cough?, How do you treat cough?, ...
# 9   [How do you treat sore throat?, what to do if ...
# 10  [How do you treat gas problems?, what to do if...
# 11  [How do you treat Skin problems?, what to do i...
# 12  [How do you treat Abdonominal Pain?, what to d...
# 13  [How do you treat Bruises?, what to do if i ge...
# 14  [How do you treat a Broken Toe?, what to do if...
# 15  [How do you treat Choking?, what to do if i ge...
# 16  [How do you treat a wound?, what to do if i ge...
# 17  [How do you treat Diarrhea?, what to do if i g...
# 18  [How do you treat a Frost bite?, what to do if...
# 19  [How do you treat Heat Exhaustion?, what to do...
# 20  [How do you treat Heat Stroke?, what to do if ...
# 21  [How do you treat a Insect Bite?, what to do i...
# 22  [How do you treat a bleeding nose?, what to do...
# 23  [How do you treat a Pulled Muscle?, what to do...
# 24  [How do you treat Rectal Bleeding?, what to do...
# 25  [How do you treat Sun Burn?, what to do if i g...
# 26  [How do you treat Testicle Pain?, what to do i...
# 27  [How do you treat a Vertigo?, what to do if i ...
# 28  [How do you treat bleeding?, what to do if i g...
# 29  [How do you treat an eye Injury?, what to do i...
# 30  [How do you treat a chemical burn?, what to do...
# 31  [How do you treat a Poison?, what to do if i g...
# 32  [How do you treat broken Teeth ?, what to do i...
# 33  [How do you treat a seizure?, what to do if i ...
# 34  [How do you treat a head Injury?, what to do i...
# 35  [How do you treat Faint?, what to do if i feel...
# 36  [How do you treat a mild Headache?, what to do...
# 37  [How do you treat a Cold?, what to do if i get...
# 38  [How do you treat Rashes?, what to do if i get...
# 39  [How do you treat a snake bite?, what to do if...
# 40  [How do you treat a animal bite?, How do you t...
# 41  [What to do if someone is Drowning?, what to d...
# 42  [How to give CPR??, what to do in a CPR?, What...
# 43  [How do you treat a Fracture?, what to do if i...
#
#                                             responses context_set
# 0   [Wash the cut properly to prevent infection an...
# 1   [Begin with washed hands.Gently clean the area...
# 2   [Remove any stingers immediately. Some experts...
# 3   [1. soak it in EPSOM salts. Dissolve a cup of ...
# 4   [Use an ice pack or ice slush bath immediately...
# 5   [Rest,Ice,Compression and Elevation can be use...
# 6   [To treat a fever at home: 1)Drink plenty of f...
# 7   [When youâ€™re stuffed up, focus on keeping yo...
# 8   [1) Honey:- Use honey to treat a cough, mix 2 ...
# 9   [1) Make sure you get plenty of rest and drink...
# 10  [1) Replenish body fluids 2)Do not take antidi...
# 11  [1)Hydrocortisone cream. 2)Ointments like cala...
# 12  [1)Provide clear fluids to sip, such as water,...
# 13  [1)Ice the bruise with an ice pack wrapped in ...
# 14  [1)To help decrease pain and swelling in a bro...
# 15  [1)Encourage them to keep coughing to try to c...
# 16  [1)Rinse the cut or wound with water and apply...
# 17  [1)Hydrating the body is essential for recover...
# 18  [1. Warm the area: Soak in warm water or use b...
# 19  [Heat exhaustion occurs when the body loses to...
# 20  [If you suspect someone has heat stroke, call ...
# 21  [1. Move to a safe area.2. Remove any stingers...
# 22  [1. Sit upright and lean forward slightly.2. P...
# 23  [1. Rest: Avoid activities causing pain, swell...
# 24  [1. Diet: Consume 25â€“30 grams of fiber daily...
# 25  [1. Take a pain reliever: Use nonprescription ...
# 26  [1. Rest and Support: Wear supportive underwea...
# 27  [1) Medication: Antihistamines, motion sicknes...
# 28  [1. Apply Pressure: Use a clean cloth, tissue,...
# 29  [1. Avoid Rubbing or Touching: Refrain from ru...
# 30  [1. Remove Contaminated Items: Quickly remove ...
# 31  [1. Call Poison Control: If poisoning is suspe...
# 32  [1. Save Broken Pieces: If feasible, save brok...
# 33  [1. Stay Calm and Safe: Remain composed and st...
# 34  [1. Assess Severity: Evaluate the head injury'...
# 35  [1. Lay the Person Down: If someone faints, ge...
# 36  [Give ibuprofen (Advil, Motrin), aspirin, or a...
# 37  [1)Keeping hydrated is absolutely vital to hel...
# 38  [1)Olive oil helps in healing and promotes ski...
# 39  [While waiting for medical help: 1)Move the pe...
# 40  [1)Wash the wound with soap and warm water. 2)...
# 41  [1)Place your ear next to the person's mouth a...
# 42  [1)For an adult or child, place the heel of on...
# 43  [1)Stop any bleeding. Apply pressure to the wo...

# %%
df_train = df[['tag', 'patterns']]

# %%
df_train
# Out:
#                           tag  \
# 0                        Cuts
# 1                   Abrasions
# 2                      stings
# 3                    Splinter
# 4                     Sprains
# 5                     Strains
# 6                       Fever
# 7            Nasal Congestion
# 8                       Cough
# 9                 Sore Throat
# 10  Gastrointestinal problems
# 11              Skin problems
# 12           Abdonominal Pain
# 13                    Bruises
# 14                 Broken Toe
# 15                    Choking
# 16                      Wound
# 17                   Diarrhea
# 18                 Frost bite
# 19            Heat Exhaustion
# 20                Heat Stroke
# 21               Insect Bites
# 22                 nose bleed
# 23              Pulled Muscle
# 24            Rectal bleeding
# 25                   Sun Burn
# 26              Testicle Pain
# 27                    Vertigo
# 28            Normal Bleeding
# 29                 Eye Injury
# 30              Chemical Burn
# 31                     Poison
# 32                      Teeth
# 33                    seizure
# 34                Head Injury
# 35                   Fainting
# 36                   Headache
# 37                       Cold
# 38                       Rash
# 39                 snake bite
# 40                animal bite
# 41                   Drowning
# 42                        CPR
# 43                   Fracture
#
#                                              patterns
# 0   [What to do if Cuts?, How to cure Cuts?, Which...
# 1   [how do you treat abrasions?, Do Abrasions cau...
# 2   [How do you treat Sting?, Stings, What to do i...
# 3   [How to remove Splinters, How to cure Splinter...
# 4   [How do you treat a sprain?, what to do if i g...
# 5   [How do you treat a strain?, what to do if i g...
# 6   [How do you treat a mild Fever?, what to do if...
# 7   [How do you treat nasal Congestion?, what to d...
# 8   [How to cure cough?, How do you treat cough?, ...
# 9   [How do you treat sore throat?, what to do if ...
# 10  [How do you treat gas problems?, what to do if...
# 11  [How do you treat Skin problems?, what to do i...
# 12  [How do you treat Abdonominal Pain?, what to d...
# 13  [How do you treat Bruises?, what to do if i ge...
# 14  [How do you treat a Broken Toe?, what to do if...
# 15  [How do you treat Choking?, what to do if i ge...
# 16  [How do you treat a wound?, what to do if i ge...
# 17  [How do you treat Diarrhea?, what to do if i g...
# 18  [How do you treat a Frost bite?, what to do if...
# 19  [How do you treat Heat Exhaustion?, what to do...
# 20  [How do you treat Heat Stroke?, what to do if ...
# 21  [How do you treat a Insect Bite?, what to do i...
# 22  [How do you treat a bleeding nose?, what to do...
# 23  [How do you treat a Pulled Muscle?, what to do...
# 24  [How do you treat Rectal Bleeding?, what to do...
# 25  [How do you treat Sun Burn?, what to do if i g...
# 26  [How do you treat Testicle Pain?, what to do i...
# 27  [How do you treat a Vertigo?, what to do if i ...
# 28  [How do you treat bleeding?, what to do if i g...
# 29  [How do you treat an eye Injury?, what to do i...
# 30  [How do you treat a chemical burn?, what to do...
# 31  [How do you treat a Poison?, what to do if i g...
# 32  [How do you treat broken Teeth ?, what to do i...
# 33  [How do you treat a seizure?, what to do if i ...
# 34  [How do you treat a head Injury?, what to do i...
# 35  [How do you treat Faint?, what to do if i feel...
# 36  [How do you treat a mild Headache?, what to do...
# 37  [How do you treat a Cold?, what to do if i get...
# 38  [How do you treat Rashes?, what to do if i get...
# 39  [How do you treat a snake bite?, what to do if...
# 40  [How do you treat a animal bite?, How do you t...
# 41  [What to do if someone is Drowning?, what to d...
# 42  [How to give CPR??, what to do in a CPR?, What...
# 43  [How do you treat a Fracture?, what to do if i...

# %%
nlp = spacy.load('en_core_web_lg')

# %%
from nltk import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
def clean(sentence):
    tokens = []
    doc = nlp(sentence)
    for token in doc:
        if token.is_alpha:
            tokens.append(str(token))
    return ' '.join(tokens)
    
def stem(sentence):
    tokens = nltk.word_tokenize(sentence)
    stemmed_tokens = []
    for token in tokens:
        stemmed_tokens.append(str(stemmer.stem(token)))

    return ' '.join(stemmed_tokens)

def lemmatize(sentence):
    lemmatized_tokens = []
    doc = nlp(sentence)
    for token in doc:
        lemmatized_tokens.append(str(token.lemma_))
    
    return ' '.join(lemmatized_tokens)

# %%
labels = {}

for i,label in enumerate(df_train['tag']):
    labels[label] = i

# %%
labels
# Out:
# {'Cuts': 0,
#  'Abrasions': 1,
#  'stings': 2,
#  'Splinter': 3,
#  'Sprains': 4,
#  'Strains': 5,
#  'Fever': 6,
#  'Nasal Congestion': 7,
#  'Cough': 8,
#  'Sore Throat': 9,
#  'Gastrointestinal problems': 10,
#  'Skin problems': 11,
#  'Abdonominal Pain': 12,
#  'Bruises': 13,
#  'Broken Toe': 14,
#  'Choking': 15,
#  'Wound': 16,
#  'Diarrhea': 17,
#  'Frost bite': 18,
#  'Heat Exhaustion': 19,
#  'Heat Stroke': 20,
#  'Insect Bites': 21,
#  'nose bleed': 22,
#  'Pulled Muscle': 23,
#  'Rectal bleeding': 24,
#  'Sun Burn': 25,
#  'Testicle Pain': 26,
#  'Vertigo': 27,
#  'Normal Bleeding': 28,
#  'Eye Injury': 29,
#  'Chemical Burn': 30,
#  'Poison': 31,
#  'Teeth': 32,
#  'seizure': 33,
#  'Head Injury': 34,
#  'Fainting': 35,
#  'Headache': 36,
#  'Cold': 37,
#  'Rash': 38,
#  'snake bite': 39,
#  'animal bite': 40,
#  'Drowning': 41,
#  'CPR': 42,
#  'Fracture': 43}

# %%
for i,patterns in enumerate(df_train['patterns']):
    Pre_proccessed_List = []
    Existing_sents_List = df_train['patterns'].loc[i]
    for sentence in Existing_sents_List:
        print(sentence)
        Pre_proccessed_List.append(lemmatize(clean(sentence)))
        Pre_proccessed_List.append(stem(clean(sentence)))
        Pre_proccessed_List.append(clean(sentence))
        Pre_proccessed_List.append(lemmatize(sentence))
        Pre_proccessed_List.append(stem(sentence))
    Existing_sents_List.extend(Pre_proccessed_List)
# Out:
# What to do if Cuts?
# How to cure Cuts?
# Which medicine to apply for Cuts?
# what to apply on cuts?
# Cuts
# how do you treat abrasions?
# Do Abrasions cause scars?
# Abrasions
# what to do if abrasions?
# Which medicine to apply for abrasions?
# How to cure abrasions?
# How do you treat Sting?
# Stings
# What to do if you get a sting?
# Which medicine to apply if sting?
# How to remove Splinters
# How to cure Splinters?
# What to do if I have splinters?
# How do you bring a splinter to the surface?
# How do you treat a sprain?
# what to do if i get a sprain?
# Which cream to apply if i get a sprain?
# Which medicine to apply if I get a sprain?
# How do you treat a strain?
# what to do if i get a strain?
# Which cream to apply if i get a strain?
# Which medicine to apply if I get a strain?
# what to do if i get a eye Injury?
# Which medicine to take if I injured my eye?
# How to cure injured eye?
# How do you treat a chemical burn?
# what to do if i get a Chemical Burn?
# Which medicine to take if I get burn due to chemicals?
# How to cure Chemical Burn?
# How do you treat a Poison?
# what to do if i get Poison?
# Which medicine to take if I am poisoned?
# How to cure Poisoning?
# How do you treat broken Teeth ?
# what to do if my Teeth got broken?
# Which medicine to take if I get broken teeth?
# cure broken teeth?
# How do you treat a seizure?
# what to do if i get a seizure?
# Which medicine to take if I get seizure?
# How to cure seizure?
# How do you treat a head Injury?
# what to do if i get a Head Injury?
# Which medicine to take if I get injured in the head?
# How to cure Head Injury?
# How do you treat Faint?
# what to do if i feel like Fainting?
# Which medicine to take if I get a Faint?
# How to cure Fainting?
# How do you treat a mild Headache?
# what to do if i get a mild Headache?
# Which medicine to take if I have a mild headache?
# How to cure a mild headache?
# How do you treat a Cold?
# what to do if i get a mild Cold?
# Which medicine to take if I have a Cold?
# How to cure Cold?
# How do you treat Rashes?
# what to do if i get a Rash?
# Which medicine to take if I have a Rash?
# How to cure Rash?
# How do you treat a snake bite?
# what to do if i get a snake bite?
# Which medicine to take if I get a snake bite?
# How to cure snake bite?
# i got bit by a snake
# How do you treat a animal bite?
# How do you treat a monkey bite?
# How do you treat a dog bite?
# what to do if i get a animal bite?
# Which medicine to take if I get a monekey bite?
# How to cure dog bite?
# i got bit by a dog
# What to do if someone is Drowning?
# what to do if someone drowned?
# What steps to take if i see a drowning person?
# How to help a drowning person?
# How to give CPR??
# what to do in a CPR?
# What steps to take in a CPR??
# How to help a drowning person in CPR?
# How do you treat a Fracture?
# what to do if i get a Fracture?
# Which medicine to take if I have a Fracture?
# How to cure a Fracture?

# %%
df_train['Numeric_label'] = df_train.tag.map(labels)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10380\2272514042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Numeric_label'] = df_train.tag.map(labels)

# %%
df_train = df_train[['patterns', 'Numeric_label']]

# %%
df_train
# Out:
#                                              patterns  Numeric_label
# 0   [What to do if Cuts?, How to cure Cuts?, Which...              0
# 1   [how do you treat abrasions?, Do Abrasions cau...              1
# 2   [How do you treat Sting?, Stings, What to do i...              2
# 3   [How to remove Splinters, How to cure Splinter...              3
# 4   [How do you treat a sprain?, what to do if i g...              4
# 5   [How do you treat a strain?, what to do if i g...              5
# 6   [How do you treat a mild Fever?, what to do if...              6
# 7   [How do you treat nasal Congestion?, what to d...              7
# 8   [How to cure cough?, How do you treat cough?, ...              8
# 9   [How do you treat sore throat?, what to do if ...              9
# 10  [How do you treat gas problems?, what to do if...             10
# 11  [How do you treat Skin problems?, what to do i...             11
# 12  [How do you treat Abdonominal Pain?, what to d...             12
# 13  [How do you treat Bruises?, what to do if i ge...             13
# 14  [How do you treat a Broken Toe?, what to do if...             14
# 15  [How do you treat Choking?, what to do if i ge...             15
# 16  [How do you treat a wound?, what to do if i ge...             16
# 17  [How do you treat Diarrhea?, what to do if i g...             17
# 18  [How do you treat a Frost bite?, what to do if...             18
# 19  [How do you treat Heat Exhaustion?, what to do...             19
# 20  [How do you treat Heat Stroke?, what to do if ...             20
# 21  [How do you treat a Insect Bite?, what to do i...             21
# 22  [How do you treat a bleeding nose?, what to do...             22
# 23  [How do you treat a Pulled Muscle?, what to do...             23
# 24  [How do you treat Rectal Bleeding?, what to do...             24
# 25  [How do you treat Sun Burn?, what to do if i g...             25
# 26  [How do you treat Testicle Pain?, what to do i...             26
# 27  [How do you treat a Vertigo?, what to do if i ...             27
# 28  [How do you treat bleeding?, what to do if i g...             28
# 29  [How do you treat an eye Injury?, what to do i...             29
# 30  [How do you treat a chemical burn?, what to do...             30
# 31  [How do you treat a Poison?, what to do if i g...             31
# 32  [How do you treat broken Teeth ?, what to do i...             32
# 33  [How do you treat a seizure?, what to do if i ...             33
# 34  [How do you treat a head Injury?, what to do i...             34
# 35  [How do you treat Faint?, what to do if i feel...             35
# 36  [How do you treat a mild Headache?, what to do...             36
# 37  [How do you treat a Cold?, what to do if i get...             37
# 38  [How do you treat Rashes?, what to do if i get...             38
# 39  [How do you treat a snake bite?, what to do if...             39
# 40  [How do you treat a animal bite?, How do you t...             40
# 41  [What to do if someone is Drowning?, what to d...             41
# 42  [How to give CPR??, what to do in a CPR?, What...             42
# 43  [How do you treat a Fracture?, what to do if i...             43

# %%
df_train = df_train.explode('patterns')

# %%
df_train.reset_index(drop=True, inplace=True)
print(df_train)
# Out:
#                                patterns  Numeric_label
# 0                   What to do if Cuts?              0
# 1                     How to cure Cuts?              0
# 2     Which medicine to apply for Cuts?              0
# 3                what to apply on cuts?              0
# 4                                  Cuts              0
# ...                                 ...            ...
# 1123             how to cure a fracture             43
# 1124              how to cure a fractur             43
# 1125             How to cure a Fracture             43
# 1126           how to cure a fracture ?             43
# 1127            how to cure a fractur ?             43
#
# [1128 rows x 2 columns]

# %%
X_train = []

for i,sv in enumerate(df_train['patterns']):
    X_train.append(nlp(sv).vector)

# %%
X_train = np.array(X_train)

# %%
X_train.shape
# Out:
# (1128, 300)

# %%
X_train_reshaped = np.reshape(X_train, (X_train.shape[0], 1, -1))

# %%
X_train = tf.convert_to_tensor(X_train_reshaped)

# %%
X_train[0].shape
# Out:
# TensorShape([1, 300])

# %%
y_train = []

for i,label in enumerate(df_train['Numeric_label']):
    y_train.append(float(label))

# %%
y_train = tf.convert_to_tensor(np.array(y_train))

# %%
y_train
# Out:
# <tf.Tensor: shape=(1128,), dtype=float64, numpy=array([ 0.,  0.,  0., ..., 43., 43., 43.])>

# %%
import datetime

# %%
# %load_ext tensorboard

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(1, 300)),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(44, activation='softmax') 
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

logdir="logs/fit/" + datetime.time().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

model.fit(X_train, y_train, epochs=100, callbacks=[tensorboard_callback])
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)                    │ (None, 1, 64)               │          19,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_2               │ (None, 64)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 44)                  │           2,860 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,284 (102.67 KB)
#  Trainable params: 26,284 (102.67 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0

# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1
# User:  How do you treat Sting?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2
# User:  "How do you handle Sting?"
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2
# User:  How do you address Sting?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2
# User:  "How do you deal with Sting?"
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 5
# User:  How do you deal with Sting?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 5
# User:  Which cream to apply if i get a sprain?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4
# User:  what to do if i get a sprain?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4
# User:  "What steps should I take if I experience a sprain?"
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# I dont Understand 0.24356623 38
# User:  "What should I do if I get a sprain?"
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# I dont Understand 0.5503315 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 2
#       1 while True:
# ----> 2     User_input = input('User: ')
#       3     sentence = clean(User_input)
#       4     doc = nlp(sentence)
#
# File D:\anaconda3\envs\tensorflow_learn\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File D:\anaconda3\envs\tensorflow_learn\Lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
while True:
    User_input = input('User: ')
    sentence = lemmatize(clean(User_input))
    doc = nlp(sentence)
    vector = doc.vector
    vector = np.reshape(vector, (-1, 1, 300))
    predictions = model.predict(vector)
    predicted_class_index = np.argmax(predictions)
    predicted_class_probability = predictions[0][predicted_class_index]
    if predicted_class_probability > 0.6:
        print(predicted_class_index)
    else:
        print('I dont Understand', predicted_class_probability, predicted_class_index)
# Out:
# User:  "What steps should I take if I experience a sprain?"
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# I dont Understand 0.4652469 26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 2
#       1 while True:
# ----> 2     User_input = input('User: ')
#       3     sentence = lemmatize(clean(User_input))
#       4     doc = nlp(sentence)
#
# File D:\anaconda3\envs\tensorflow_learn\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File D:\anaconda3\envs\tensorflow_learn\Lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
model.save('D:\\HWAN\\Models\\First_Aid_Recommendations\\AidSyncModel.keras')
